# %% [markdown]
# # Modeling
# In this exercise, we will predict activity on drd1 ligands. We will use regresion forms of [SVM](https://en.wikipedia.org/wiki/Support-vector_machine) and [Random Forest](https://en.wikipedia.org/wiki/Random_forest). This methods are good, but they allways give you some results, so remember garbage in, garbage out. We will use again
# scikit [SVR](https://scikit-learn.org/stable/modules/svm.html#regression) and [RF](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html?highlight=random%20forest#sklearn.ensemble.RandomForestRegressor).

# %% [markdown]
# ## What to do?
# * Familiarize yourself with modeling. If mentioned models in this exercise are not enough, you can surely find more methods in scikit-learn. You can use another descriptors, e.g. fingerprints.
# * Find some well predictig solution set of model and descriptors on your data

# %%
from scipy.spatial import distance
from sklearn import manifold
from sklearn import decomposition
from sklearn import preprocessing
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn import svm
from sklearn import ensemble
from sklearn import model_selection as ms
from sklearn.metrics import mean_squared_error

# rdkit mols are displayed as images
from rdkit.Chem.Draw import IPythonConsole

from rdkit.Chem import AllChem as Chem
from rdkit import DataStructs
from rdkit.Chem.SaltRemover import SaltRemover

# descriptors
from rdkit.Chem import Lipinski
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import Descriptors

# plots
from matplotlib import pyplot
import seaborn

# other packages
import pandas as pd
import numpy as np
import csv
import re

from sklearn.preprocessing import StandardScaler
# Out:
# RDKit WARNING: [23:02:13] Enabling RDKit 2019.09.3 jupyter extensions

# %% [markdown]
# ## Standardization
#
# Before we start with model training, we should clean our data - standardize compounds. In our case, it means removal of salts, inorganics and [neutralization](https://rdkit.readthedocs.io/en/latest/Cookbook.html#neutralizing-charged-molecules). You can use tautomerization or some advanced packages like [molvs](https://molvs.readthedocs.io/en/latest/).

# %%
sr = SaltRemover() # from rdkit
m = Chem.MolFromSmiles("[Na+].C(=O)[O-]")
print(Chem.MolToSmiles(sr(m)))
# Out:
# O=C[O-]

# %%
""" contribution from Hans de Winter """
def _InitialiseNeutralisationReactions():
    patts= (
        # Imidazoles
        ('[n+;H]','n'),
        # Amines
        ('[N+;!H0]','N'),
        # Carboxylic acids and alcohols
        ('[$([O-]);!$([O-][#7])]','O'),
        # Thiols
        ('[S-;X1]','S'),
        # Sulfonamides
        ('[$([N-;X2]S(=O)=O)]','N'),
        # Enamines
        ('[$([N-;X2][C,N]=C)]','N'),
        # Tetrazoles
        ('[n-]','[nH]'),
        # Sulfoxides
        ('[$([S-]=O)]','S'),
        # Amides
        ('[$([N-]C=O)]','N'),
        )
    return [(Chem.MolFromSmarts(x),Chem.MolFromSmiles(y,False)) for x,y in patts]

_reactions=None
def NeutraliseCharges(mol, reactions=None):
    global _reactions
    if reactions is None:
        if _reactions is None:
            _reactions=_InitialiseNeutralisationReactions()
        reactions=_reactions
    replaced = False
    for i,(reactant, product) in enumerate(reactions):
        while mol.HasSubstructMatch(reactant):
            replaced = True
            rms = Chem.ReplaceSubstructs(mol, reactant, product)
            mol = rms[0]
    return mol, replaced

# %%
smis=("c1cccc[nH+]1",
      "C[N+](C)(C)C","c1ccccc1[NH3+]",
      "CC(=O)[O-]","c1ccccc1[O-]",
      "CCS",
      "C[N-]S(=O)(=O)C",
      "C[N-]C=C","C[N-]N=C",
      "c1ccc[n-]1",
      "CC[N-]C(=O)CC")
for smi in smis:
    (molSmiles, neutralised) = NeutraliseCharges(Chem.MolFromSmiles(smi))
    print(smi + "->" + Chem.MolToSmiles(molSmiles))
# Out:
# c1cccc[nH+]1->c1ccncc1
# C[N+](C)(C)C->C[N+](C)(C)C
# c1ccccc1[NH3+]->Nc1ccccc1
# CC(=O)[O-]->CC(=O)O
# c1ccccc1[O-]->Oc1ccccc1
# CCS->CCS
# C[N-]S(=O)(=O)C->CNS(C)(=O)=O
# C[N-]C=C->C=CNC
# C[N-]N=C->C=NNC
# c1ccc[n-]1->c1cc[nH]c1
# CC[N-]C(=O)CC->CCNC(=O)CC

# %%
_saltRemover = SaltRemover()
_inorganicPatt = Chem.MolFromSmarts("[!#6;!#7;!#8;!#16;!F;!Cl;!Br;!I]") # to remove compounds with unwanted atom types
_carbonPatt = Chem.MolFromSmarts("[#6]") # to remove compounds without carbon - inorganic
def standardize(mol):
    if mol.HasSubstructMatch(_carbonPatt):
        mol = _saltRemover(mol)
        if mol.GetNumAtoms()==0:
            return None
        else:
            mol, neutralized = NeutraliseCharges(mol)
            if mol.HasSubstructMatch(_inorganicPatt):
                return None
            else:
                # Sanitize mol, without sanitization some structures can't be drawn or fingerprinted
                Chem.SanitizeMol(mol) # add catch block?
                return mol
    else:
        return None

# %% [markdown]
# ## Data loading

# %%
# some pChEMBL values in our file are not valid floats
float_pattern = re.compile("[0-9]+(\.[0-9]*)?")
# function for Lipinski's descriptors
lip_func = [("HBA", Lipinski.NumHAcceptors), ("HBD", Lipinski.NumHDonors), ("MW", Descriptors.ExactMolWt),
            ("LogP", Descriptors.MolLogP), ("TPSA", rdMolDescriptors.CalcTPSA), ("RB", Lipinski.NumRotatableBonds)]
# load drd1, we want to remember source of data and Standard and pChEMBLE value (it's transfomed compound activity to "standard" value)
with open("DRD1.csv") as inp:
    drd1 = [row for row in csv.DictReader(inp, delimiter=";", quotechar='"')]
    for m in drd1:
        mol = Chem.MolFromSmiles(m["Smiles"])
        if m['Smiles'] != '':
            if mol:
                m["rdmol"] = mol
                stdmol = standardize(mol)
                m["source"] = "drd1"
                m["pChEMBL Value"] = float(m["pChEMBL Value"]) if float_pattern.match(m["pChEMBL Value"]) else 0
                m["std_rdmol"] = None
                m["Standard Value"] = float(m["Standard Value"]) if float_pattern.match(m["Standard Value"]) else np.NaN
            if stdmol:
                m["std_rdmol"] = stdmol
                m["std_smiles"] = Chem.MolToSmiles(stdmol)
                m["fps"] = Chem.GetMorganFingerprintAsBitVect(m["std_rdmol"],2,nBits=1024)
                for f in lip_func:
                    m[f[0]] = f[1](m["std_rdmol"])
        else:
            drd1.remove(m)

# %%
for m in drd1:
    try:
        m["std_rdmol"]
    except:
#         print("An exception occurred")
        m["std_rdmol"] = None

# %%
# let's work with Pandas dataframe
df = pd.DataFrame([m for m in drd1 if m["std_rdmol"]], columns=["Smiles", "std_smiles", "source", "rdmol", "std_rdmol", "fps", "Standard Value", "pChEMBL Value", *(f[0] for f in lip_func)])
# adds index as normal column
# MQN = molecular quantum numbers
df.reset_index(level=0, inplace=True)
df = df.join(pd.DataFrame((rdMolDescriptors.MQNs_(mol) for mol in df["std_rdmol"]),
                          columns=[*(f"MQN_{x}" for x in range(1,43))])
            )

# %%
mx = df["Standard Value"].max()+1
df["Standard Value"] = df["Standard Value"].fillna(mx+1)

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# ## SVR

# %%
svr = svm.SVR()
svr.fit(df[df["Standard Value"]<mx][(f"MQN_{x}" for x in range(1, 43))], df[df["Standard Value"]<mx]["Standard Value"])
# Out:
# SVR()

# %%
res = pd.DataFrame(svr.predict(df[(f"MQN_{x}" for x in range(1, 43))])).join(df[["Standard Value"]])
res.columns = ["Prediction", "Standard Value"]
(res["Prediction"]-res["Standard Value"]).abs().mean()
# Out:
# 75231.35815668188

# %% [markdown]
# ### Let's use some function to get results, we will have lots of models

# %%
def get_results(model, data, descriptors, predicted_value):
    res = pd.DataFrame(model.predict(data[descriptors])).join(data[[predicted_value]])
    res.columns = ["Prediction", predicted_value]
    print(f"""Average error whole set: {(res["Prediction"]-res[predicted_value]).abs().mean()}""")
    return res

# %%
res = get_results(svr, df, (f"MQN_{x}" for x in range(1, 43)), "Standard Value")
# Out:
# Average error whole set: 75231.35815668188

# %%
fig, ax = pyplot.subplots(figsize=(15,10))
p=seaborn.scatterplot(x="Prediction",
                      y="Standard Value",
                      data=res,
                      legend="brief",
                      ax=ax,
                      alpha=0.75
                     )

# %%
fig, ax = pyplot.subplots(figsize=(15,10))
p=seaborn.scatterplot(x="Prediction",
                      y="Standard Value",
                      data=res[res["Standard Value"]<mx],
                      legend="brief",
                      ax=ax,
                      alpha=0.75
                     )

# %%
fig, ax = pyplot.subplots(figsize=(15,10))
p=seaborn.scatterplot(x="Prediction",
                      y="Standard Value",
                      data=res[res["Standard Value"]<mx/1000],
                      legend="brief",
                      ax=ax,
                      alpha=0.75
                     )

# %% [markdown]
# ## Random forest

# %%
rf = ensemble.RandomForestRegressor()
rf.fit(df[df["Standard Value"]<mx][(f"MQN_{x}" for x in range(1, 43))], df[df["Standard Value"]<mx]["Standard Value"])
# Out:
# RandomForestRegressor()

# %%
res_rf = get_results(rf, df, (f"MQN_{x}" for x in range(1, 43)), "Standard Value")
# Out:
# Average error whole set: 67365.22788801513

# %%
fig, ax = pyplot.subplots(figsize=(15,10))
p=seaborn.scatterplot(x="Prediction",
                      y="Standard Value",
                      data=res_rf,
                      legend="brief",
                      ax=ax,
                      alpha=0.75
                     )

# %%
fig, ax = pyplot.subplots(figsize=(15,10))
p=seaborn.scatterplot(x="Prediction",
                      y="Standard Value",
                      data=res_rf[res_rf["Standard Value"]<mx/1000][res_rf["Prediction"]<1e6],
                      legend="brief",
                      ax=ax,
                      alpha=0.75
                     )
# Out:
# C:\Users\elieb\miniconda3\envs\cdd\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %% [markdown]
# You can see the range of values is pretty broad. Maybe, log values will be better. Let's try pChEMBL Value.

# %% [markdown]
# # PCHEMBL
# I am going to predict pChEMBL value. The features are going to be either MQN, PCA or later fingerprints.
#
# ## SVR

# %%
svr_p = svm.SVR()
svr_p.fit(df[df["pChEMBL Value"]>0][(f"MQN_{x}" for x in range(1, 43))], df[df["pChEMBL Value"]>0]["pChEMBL Value"])
# Out:
# SVR()

# %%
res_svr_p = get_results(svr_p, df, (f"MQN_{x}" for x in range(1, 43)), "pChEMBL Value")
# Out:
# Average error whole set: 4.93133774091559

# %%
fig, ax = pyplot.subplots(figsize=(15,10))
p=seaborn.scatterplot(x="Prediction",
                      y="pChEMBL Value",
                      data=res_svr_p[res_svr_p["pChEMBL Value"]>0],
                      legend="brief",
                      ax=ax,
                      alpha=0.75
                     )

# %% [markdown]
# ## SVR with PCA

# %%
norm = preprocessing.normalize(df[(f"MQN_{x}" for x in range(1, 43))])
pca = decomposition.PCA(n_components=42)
pca.fit(norm)
df = df.join(pd.DataFrame(pca.transform(norm), columns=[f"nPCA_{x}" for x in range(1, 43)]))

# %%
svr_np = svm.SVR()
svr_np.fit(df[df["Standard Value"]<mx][(f"nPCA_{x}" for x in range(1, 43))], df[df["Standard Value"]<mx]["pChEMBL Value"])
# Out:
# SVR()

# %%
res_svr_np = res = get_results(svr_np, df, (f"nPCA_{x}" for x in range(1, 43)), "pChEMBL Value")
# Out:
# Average error whole set: 3.9589786033500047

# %%
fig, ax = pyplot.subplots(figsize=(15,10))
p=seaborn.scatterplot(x="Prediction",
                      y="pChEMBL Value",
                      data=res_svr_np[res_svr_np["pChEMBL Value"]>0],
                      legend="brief",
                      ax=ax,
                      alpha=0.75
                     )

# %% [markdown]
# ## SVR with other kernel

# %%
svr_poly = svm.SVR(kernel='poly')
svr_poly.fit(df[df["Standard Value"]<mx][(f"nPCA_{x}" for x in range(1, 43))], df[df["Standard Value"]<mx]["pChEMBL Value"])
# Out:
# SVR(kernel='poly')

# %%
res_poly = get_results(svr_poly, df, (f"nPCA_{x}" for x in range(1, 43)), "pChEMBL Value")
# Out:
# Average error whole set: 4.233017488180964

# %%
fig, ax = pyplot.subplots(figsize=(15,10))
p=seaborn.scatterplot(x="Prediction",
                      y="pChEMBL Value",
                      data=res_poly[res_poly["pChEMBL Value"]>0],
                      legend="brief",
                      ax=ax,
                      alpha=0.75
                     )

# %% [markdown]
# ## RF with pChEMBL Value

# %%
rf_poly = ensemble.RandomForestRegressor()
rf_poly.fit(df[df["pChEMBL Value"]<mx][(f"MQN_{x}" for x in range(1, 43))], df[df["pChEMBL Value"]<mx]["pChEMBL Value"])
# Out:
# RandomForestRegressor()

# %%
res_rf_poly = get_results(rf_poly, df, (f"MQN_{x}" for x in range(1, 43)), "pChEMBL Value")
# Out:
# Average error whole set: 0.3798413502394795

# %% [markdown]
# whole set vs drd1 difference?!

# %%
fig, ax = pyplot.subplots(figsize=(15,10))
p=seaborn.scatterplot(x="Prediction",
                      y="pChEMBL Value",
                      data=res_rf_poly[res_rf_poly["pChEMBL Value"]>0],
                      legend="brief",
                      ax=ax,
                      alpha=0.75
                     )

# %% [markdown]
# ## We need test set
# So, we divide our data in some ration (default is 75:25, but 80:20-70:30 is usually OK)

# %%
trainset, testset = ms.train_test_split(df[df["pChEMBL Value"]>0])

# %%
trainset.reset_index(inplace=True)
testset.reset_index(inplace=True)

# %%
from scipy.stats.stats import pearsonr
def show_errors(model, testset, test_results, features, pred_feature):
    print("R^2: %0.2f" % model.score(features, testset[pred_feature]))
    print("R: %0.2f" % np.sqrt(model.score(features, testset[pred_feature])))
    print("MSE: %0.2f" %  mean_squared_error(test_results["Prediction"], test_results[pred_feature]))
    pearson,_ = pearsonr(test_results["Prediction"], test_results[pred_feature])
    print(f"Pearson %0.2f" % pearson)

# %%
def plot_graphs(train_results, test_results, pred_feature):
    fig, ax = pyplot.subplots(figsize=(15,10))
    p=seaborn.scatterplot(x="Prediction",
                          y=pred_feature,
                          data=train_results,
                          legend="brief",
                          ax=ax,
                          alpha=0.7
                         ).set_title('Train', size=22)
    
    fig, ax = pyplot.subplots(figsize=(15,10))
    p=seaborn.scatterplot(x="Prediction",
                          y=pred_feature,
                          data=test_results,
                          legend="brief",
                          ax=ax,
                          alpha=0.75
                         ).set_title('Test', size=22)

# %%
len(trainset), len(testset)
# Out:
# (141, 47)

# %% [markdown]
# ### RF + MQN

# %%
finaly_good_model = ensemble.RandomForestRegressor()
finaly_good_model.fit(trainset[(f"MQN_{x}" for x in range(1, 43))], trainset["pChEMBL Value"])
# Out:
# RandomForestRegressor()

# %%
train_results = get_results(finaly_good_model, trainset, (f"MQN_{x}" for x in range(1, 43)), "pChEMBL Value")
# Out:
# Average error whole set: 0.4331541858957061

# %%
test_results = get_results(finaly_good_model, testset, (f"MQN_{x}" for x in range(1, 43)), "pChEMBL Value")
# Out:
# Average error whole set: 0.7321816761208786

# %%
show_errors(finaly_good_model, testset, test_results, 
            testset[(f"MQN_{x}" for x in range(1, 43))], 
            pred_feature = "pChEMBL Value")
# Out:
# R^2: 0.49
# R: 0.70
# MSE: 0.96
# Pearson 0.71

# %%
plot_graphs(train_results, test_results, "pChEMBL Value")

# %% [markdown]
# ### RF + PCA

# %%
rf_np = ensemble.RandomForestRegressor()
rf_np.fit(trainset[(f"nPCA_{x}" for x in range(1, 43))], trainset["pChEMBL Value"])
# Out:
# RandomForestRegressor()

# %%
train_results = get_results(rf_np, trainset, (f"nPCA_{x}" for x in range(1, 43)), "pChEMBL Value")
# Out:
# Average error whole set: 0.42132583051057987

# %%
test_results = get_results(rf_np, testset, (f"nPCA_{x}" for x in range(1, 43)), "pChEMBL Value")
# Out:
# Average error whole set: 0.7409118061136138

# %%
show_errors(rf_np, testset, test_results, testset[(f"nPCA_{x}" for x in range(1, 43))], "pChEMBL Value")
# Out:
# R^2: 0.50
# R: 0.70
# MSE: 0.96
# Pearson 0.72

# %%
plot_graphs(train_results, test_results, "pChEMBL Value")

# %% [markdown]
# This looks worse.

# %% [markdown]
# ## Let's use fingerprints:
# - rf + fingerprint
# - svm + fingerprint
# - KNN + fingerprint
# - adaboost + fps

# %% [markdown]
# ## Data adjustment
# For the model to be able to work with fps

# %%
scaler = StandardScaler()
X_train = np.array(list(trainset['fps']))
X_train= scaler.fit_transform(X_train)

X_test = np.array(list(testset['fps']))
X_test= scaler.fit_transform(X_test)

# %%
def get_results_fps(model, data, data_descriptors, predicted_value):
    res = pd.DataFrame(model.predict(data_descriptors)).join(data[[predicted_value]])
    res.columns = ["Prediction", predicted_value]
    print(f"""Average error whole set: {(res["Prediction"]-res[predicted_value]).abs().mean()}""")
    return res

# %% [markdown]
# ## RF + fingerprint

# %%
rf_fps = ensemble.RandomForestRegressor()
rf_fps.fit(X_train, trainset["pChEMBL Value"])
# Out:
# RandomForestRegressor()

# %%
train_results = get_results_fps(rf_fps, trainset, X_train, "pChEMBL Value")
# Out:
# Average error whole set: 0.36423405845712964

# %%
test_results = get_results_fps(rf_fps, testset, X_test, "pChEMBL Value")
# Out:
# Average error whole set: 0.6936660470983269

# %%
show_errors(rf_fps, testset, test_results, X_test, pred_feature = "pChEMBL Value")
# Out:
# R^2: 0.57
# R: 0.75
# MSE: 0.83
# Pearson 0.78

# %%
plot_graphs(train_results, test_results, "pChEMBL Value")

# %% [markdown]
# ## SVM + fingerprint

# %%
svr_poly = svm.SVR(kernel='poly')
svr_poly.fit(X_train, trainset["pChEMBL Value"])
# Out:
# SVR(kernel='poly')

# %%
train_results = get_results_fps(rf_fps, trainset, X_train, "pChEMBL Value")
# Out:
# Average error whole set: 0.36423405845712964

# %%
test_results = get_results_fps(rf_fps, testset, X_test, "pChEMBL Value")
# Out:
# Average error whole set: 0.6936660470983269

# %%
show_errors(rf_fps, testset, test_results, X_test, pred_feature = "pChEMBL Value")
# Out:
# R^2: 0.57
# R: 0.75
# MSE: 0.83
# Pearson 0.78

# %%
plot_graphs(train_results, test_results, "pChEMBL Value")

# %% [markdown]
# ## k-NN + fingerprint

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=4)
knn.fit(X_train, trainset["pChEMBL Value"])
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
train_results = get_results_fps(knn, trainset, X_train, "pChEMBL Value")
# Out:
# Average error whole set: 0.800531914893617

# %%
test_results = get_results_fps(knn, testset, X_test, "pChEMBL Value")
# Out:
# Average error whole set: 0.9539893617021278

# %%
show_errors(knn, testset, test_results, X_test, pred_feature = "pChEMBL Value")
# Out:
# R^2: 0.31
# R: 0.56
# MSE: 1.31
# Pearson 0.66

# %%
plot_graphs(train_results, test_results, "pChEMBL Value")

# %% [markdown]
# ## Adabost + fps

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada.fit(X_train, trainset["pChEMBL Value"])
# Out:
# AdaBoostRegressor()

# %%
train_results = get_results_fps(ada, trainset, X_train, "pChEMBL Value")
# Out:
# Average error whole set: 0.5841204192993098

# %%
test_results = get_results_fps(ada, testset, X_test, "pChEMBL Value")
# Out:
# Average error whole set: 0.7234168888463715

# %%
show_errors(ada, testset, test_results, X_test, pred_feature = "pChEMBL Value")
# Out:
# R^2: 0.54
# R: 0.74
# MSE: 0.88
# Pearson 0.82

# %%
plot_graphs(train_results, test_results, "pChEMBL Value")

# %% [markdown]
# ## Summary

# %% [markdown]
# I have tried a lot of combinations out of which the last one - Adaboost with fingerprints - performed best (according to the metrics: R, R^2, MSE, Pearson correlation coefficient). I would probably use this combination for predictions in case I would not have found anything better. Overall, the performance of the models is not as good as I'd expect.
